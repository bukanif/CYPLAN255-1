# %%
from matplotlib import pyplot as plt
import pandas as pd
colors = ['b','g','r','c','m','y','orange','purple']

# %%
sv = pd.read_csv('data/Remittances Survey.csv')
sv = sv.rename(columns={ 'Are you an immigrant / member of a diaspora community?':'immigrant',
                          'If so, what country are you from?':'country_from',
                        'Do you send money (or goods) to loved ones in another country?':'send_rem',
                        'What country do you send money/goods to? (Select one)':'send_country',
                       'Who are the recipients of what you send?':'recipients',
                       'What platform(s) do you use to send these things to your loved ones?':'plat_used',
                       'What do your loved ones spend the cash remittances on?':'spending',
                       'As a resource sender, would you/your family consider directly paying for clean energy products, rather than sending cash?':'demand'
                       '(Optional) Are there any factors making it harder for you/your loved ones to SEND or RECEIVE the remittances? (ie. fees, wait time, etc.)':'barriers' 
                       })
sv
# Out:
#                      Timestamp immigrant   country_from             send_rem  \
# 0    2022/04/12 4:42:52 PM MDT       Yes        Nigeria             Yes I do
# 1    2022/04/12 5:02:22 PM MDT       Yes          China  Yes, my family does
# 2    2022/04/12 5:02:33 PM MDT        No          China  Yes, my family does
# 3    2022/04/12 5:06:49 PM MDT       Yes      Hong Kong       No, not at all
# 4    2022/04/12 5:09:07 PM MDT       Yes         Mexico       No, not at all
# 5    2022/04/12 5:21:52 PM MDT       Yes          China             Yes I do
# 6    2022/04/12 6:16:57 PM MDT       Yes     Madagascar             Yes I do
# 7   2022/04/12 10:43:52 PM MDT       Yes          Kenya             Yes I do
# 8   2022/04/12 10:44:32 PM MDT       Yes          Syria             Yes I do
# 9    2022/04/13 5:30:59 AM MDT       Yes    Afghanistan             Yes I do
# 10   2022/04/13 5:54:52 AM MDT       Yes        Georgia             Yes I do
# 11   2022/04/13 7:41:38 AM MDT       Yes         Brazil  Yes, my family does
# 12  2022/04/13 10:45:03 AM MDT       Yes    Philippines  Yes, my family does
# 13  2022/04/13 11:11:26 AM MDT       Yes    Philippines             Yes I do
# 14  2022/04/13 11:30:08 AM MDT       Yes      Argentina             Yes I do
# 15   2022/04/13 8:35:05 PM MDT       Yes       Colombia             Yes I do
# 16   2022/04/16 2:24:21 PM MDT       Yes        Nigeria             Yes I do
# 17   2022/04/16 2:36:43 PM MDT       Yes          China  Yes, my family does
# 18   2022/04/16 2:54:00 PM MDT       Yes          Ghana             Yes I do
# 19   2022/04/16 2:56:16 PM MDT       Yes        Nigeria             Yes I do
# 20   2022/04/18 8:43:09 AM MDT       Yes       Honduras  Yes, my family does
# 21   2022/04/18 1:10:50 PM MDT       Yes        Eritrea             Yes I do
# 22   2022/04/18 1:43:13 PM MDT     Maybe          China  Yes, my family does
# 23   2022/04/18 8:26:13 PM MDT     Maybe         Mexico  Yes, my family does
# 24   2022/04/19 6:09:45 AM MDT       Yes        Nigeria  Yes, my family does
# 25  2022/04/19 10:15:01 AM MDT       Yes          China             Yes I do
# 26  2022/04/19 12:53:25 PM MDT       Yes          Sudan             Yes I do
# 13  Household expenses (rent, electricity, gas, fo...
# 14  In general, I buy goods from them here (clothe...
# 15  Household expenses (rent, electricity, gas, fo...
# 16  Household expenses (rent, electricity, gas, fo...
# 17  Household expenses (rent, electricity, gas, fo...
# 18  Household expenses (rent, electricity, gas, fo...
# 19  Household expenses (rent, electricity, gas, fo...
# 20  Household expenses (rent, electricity, gas, fo...
# 21  Household expenses (rent, electricity, gas, fo...
# 22  Household expenses (rent, electricity, gas, fo...
# 23  Household expenses (rent, electricity, gas, fo...
# 24  Household expenses (rent, electricity, gas, fo...
# 25  Household expenses (rent, electricity, gas, fo...
# 26  Household expenses (rent, electricity, gas, fo...
# 27  Household expenses (rent, electricity, gas, fo...
# 28  Household expenses (rent, electricity, gas, fo...
# 29  Household expenses (rent, electricity, gas, fo...
# 30  Household expenses (rent, electricity, gas, fo...
#
#    (Optional) Are there any factors making it harder for you/your loved ones to SEND or RECEIVE the remittances? (ie. fees, wait time, etc.)  \
# 0       Wait time also restrictions from home country
# 1                                                 NaN
# 2                                                 NaN
# 3   transaction fees, fear that it might not get t...
# 4                                                 NaN
# 5                                          Wait time
# 6                                     No there aren't
# 7   Integration of different financial and banking...
# 8                                Economic sensations
# 9   Sanctions on banking sectors delays the transa...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Many! a) If I transfer money from my American ...
# 15                                                NaN
# 16                                         Wait time
# 17                                                NaN
# 18                                                NaN
# 19                                   Transaction fees
# 20                                                NaN
# 21  Wait times on the family members’ end make it ...
# 22                                                NaN
# 23                                                 No
# 24                                                NaN
# 25                                                NaN
# 26                                              Fees.
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#    Briefly describe what you think is missing from your country's energy landscape (ie. consistent lighting, cooking, refrigeration, AC, etc.)  \
# 0                              Consistent electricity
# 1                                                 Idk
# 2                                             Nothing
# 3                    grid is dirty (from coal and NG)
# 4   widespread equitable access to energy, both in...
# 5   I don’t know too much about it but maybe some ...
# 6   Clean cooking fuels and products (almost the e...
# 7   The energy landscape is heavily monopolised by...
# 8                                                  AC
# 9                                   All of the above
# 10                                           Nothing
# 11  These items are all available in Brazil they a...
# 12                                                IDK
# 13                               Consistent lighting
# 14  We have good energy and very cheap. But it is ...
# 15                                           The cost
# 16                            Consistent Electricity
# 17                                                NaN
# 18  Ghana has similar energy inconsistency as Nige...
# 19                 Consistent, affordable electricity
# 20     Consistent lighting, heating & cooling system
# 21           Consistent electricity and running water
# 22  I don’t think China is missing what you listed...
# 23  Cooking, refrigeration, street lighting, publi...
# 24                                Consistent lighting
# 25              Cheap light in some places. Not sure
# 26                       Solar panels or water pumps
# 27  All of the above.  Electricity is inconsistent...
# 28             Consistent electricity infrastructure
# 29  Refrigeration is a challenge given the cost of...
# 30                   electric charging points for EVs
#
#    demand  \
# 0   Maybe
# 1      No
# 2     Yes
# 3      No
# 4      No
# 5      No
# 6   Maybe
# 7      No
# 8   Maybe
# 9   Maybe
# 10     No
# 11    Yes
# 12  Maybe
# 13     No
# 14     No
# 15  Maybe
# 16    Yes
# 17     No
# 18    Yes
# 19     No
# 20     No
# 21    Yes
# 22  Maybe
# 23  Maybe
# 24  Maybe
# 25     No
# 26     No
# 27     No
# 28     No
# 29     No
# 30     No
#
#    (Optional) To make this possible for your loved ones, are there any other factors we should consider?
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   my family doesn't care or have an awareness/kn...
# 4                                                 NaN
# 5                                                 NaN
# 6   Need to consider how feasible it is to use the...
# 7   I personally would not send money to the gover...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Tradition runs very deep. My grandmother raise...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Ghana is still struggling for E so taking 5-10...
# 19  Nobody will want to participate in this when t...
# 20  Corruption levels in the country - As it stand...
# 21  Much of the energy resources are controlled by...
# 22                                                NaN
# 23  Pricing , delivery timing of products and reli...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Information. I think there isn't enough inform...
# 29  I like the idea and would maybe use it to supp...
# 30                                                NaN

# %%
plt.figure(figsize=(10,7))
plt.title('What country do you send money/goods to?', fontsize=16)
sv.value_counts('send_country').plot(kind='bar', color=['c','g','r','r','r','r','m','m','m','m','m','m','m','m','m','m','m','m','m'])
# Out:
# <AxesSubplot:title={'center':'What country do you send money/goods to?'}, xlabel='send_country'>

# %%
plt.figure(figsize=(10,7))
sv.value_counts('send_rem').plot(kind='pie', colors=colors, fontsize=14, ylabel="")
plt.title('Do you send money (or goods) to loved ones in another country?',fontsize=14)
plt.legend(labels=sv.value_counts('send_rem'), loc='upper right')
plt.show()

# %%
recip = {'Parents':16 , 'Children':1, 'Siblings':9,'Grandparents':6,'Aunts, uncles, cousins':9,'Greater community':6, 'Friends':3} 
recip = pd.Series(recip).sort_values(ascending=False)
plt.figure(figsize=(10,7))
recip.plot(kind='bar', color=colors, fontsize=12)
plt.title('Who are the recipients of what you send?',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Who are the recipients of what you send?')

# %%
spend = {'Household':27 ,'Education':10,'Business':2,'Medical':10,'Saving':3, 'IDK':2 } 
spend = pd.Series(spend).sort_values(ascending=False)
fig,ax = plt.subplots(figsize=(10,7))
plt.title('What expenses do your loved ones spend the cash remittances on?', fontsize=16)
spend.plot(kind='bar',color=colors)
# Out:
# <AxesSubplot:title={'center':'What expenses do your loved ones spend the cash remittances on?'}>

# %%
plat = {'Western Union':19,'Moneygram':5,'Bank of China':3,'Xoom':2,'World Remit':1,'Mpesa':1,'Indian Bank':1,'Remitly': 1,'Chipper':1,'Binance':1, 'Sendwave':1, 'Zelle':1} 
plat = pd.Series(plat)
plt.figure(figsize=(10,7))
plat.plot(kind='bar', color=colors)
plt.title('What platform(s) do you use to send money to your loved ones?',fontsize=14)
# Out:
# Text(0.5, 1.0, 'What platform(s) do you use to send money to your loved ones?')

# %%
plt.figure(figsize=(10,7))
sv.value_counts('demand').plot(kind='pie', colors=['r','orange','g'], ylabel='')
plt.legend(labels=sv.value_counts('demand'), loc='upper right')
plt.title('Would you consider directly paying for clean energy products, rather than sending cash?',fontsize=14)
plt.show()
